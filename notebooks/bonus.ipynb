# %% [markdown]
# Universidad Torcuato Di Tella

# %% [markdown]
# Licenciatura en Tecnología Digital
#
# **Aplicaciones Computacionales en Negocios**

# %% [markdown]
# # **Trabajo Práctico N°1 — Sistema de abordaje de pasajeros en un avión**

# %% [markdown]
# En este notebook, se hará una exploración adicional más álla de lo indicado por la consigna. Aquí trataremos tópicos adicionales que se nos fue ocurriendo a medida que desarrollabamos el notebook principal del trabajo.
